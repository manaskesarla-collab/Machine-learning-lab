# %% [markdown]
# <a href="https://colab.research.google.com/github/manaskesarla-collab/Machine-learning-lab/blob/main/1DS25AI056_LAB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_csv("EDA_100_rows_6_columns.csv")

# %%
ds.head()
# Out:
#     Student_ID  Gender  Study_Hours  Attendance_%  Assignments_Completed  \
# 0  Student_001    Male          5.8          80.7                      6
# 1  Student_002  Female          4.8          93.7                      4
# 2  Student_003    Male          4.3          58.7                      9
# 3  Student_004    Male          4.0          80.2                      4
# 4  Student_005    Male          1.8          81.1                      7
#
#    Final_Marks
# 0        100.0
# 1         81.1
# 2        100.0
# 3         67.4
# 4         75.3

# %%
sns.heatmap(ds.isnull(), cbar=True)
plt.title('Missing Data Heatmap')
plt.show()

# %%
ds = df

ds['Study_Hours'] = ds['Study_Hours'].fillna(ds['Study_Hours'].median())

# Correcting column name from 'Attendence_percentage' to 'Attendance_%'
ds['Attendance_%'] = ds['Attendance_%'].fillna(ds['Attendance_%'].median())

print(ds.isnull().sum())
# Out:
# Student_ID               0
# Gender                   0
# Study_Hours              0
# Attendance_%             0
# Assignments_Completed    0
# Final_Marks              0
# dtype: int64

# %%
ds = [ds.duplicated()]

# %%
ds = ds.drop_duplicates()

# %%
ds.describe()
# Out:
#        Study_Hours  Attendance_%  Assignments_Completed  Final_Marks
# count    99.000000     99.000000              99.000000    99.000000
# mean      4.661616     78.908081               6.757576    89.279798
# std       2.226588     10.567255               2.325945    11.201649
# min       1.000000     53.700000               3.000000    63.400000
# 25%       3.600000     69.950000               4.000000    81.350000
# 50%       4.500000     80.600000               7.000000    90.500000
# 75%       5.400000     85.550000               9.000000    96.800000
# max      20.000000    100.000000              10.000000   150.000000

# %%
ds['Study_Hours'].mean()
ds['Attendance_%'].mean()
ds['Assignments_Completed'].mean()
ds['Final_Marks'].mean()
# Out:
# np.float64(89.279797979798)

# %%
ds['Assignments_Completed'].mean()
# Out:
# np.float64(6.757575757575758)

# %%
ds['Gender'].value_counts()
# Out:
# Gender
# Female    56
# Male      43
# Name: count, dtype: int64

# %%
ds['Gender'].value_counts().plot(kind='bar')
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("No of students")
plt.show()

# %%
plt.hist(ds['Study_Hours'],bins = 20)
plt.title("Distribution of study hours")
plt.xlabel("Study Hours")
plt.ylabel("No of students")
plt.show()

# %%
sns.boxplot(x=ds['Final_Marks'])
plt.title("Final Marks - Outlier distribution")
plt.show()

# %%
outliers = ds[(ds['Study_Hours'] < lower_limit) | (ds['Study_Hours'] > upper_limit)]

outliers
# Out:
#      Student_ID  Gender  Study_Hours  Attendance_%  Assignments_Completed  \
# 73  Student_074  Female          8.9          85.8                      6
# 85  Student_086    Male          8.4          91.1                      7
# 94  Student_095  Female         20.0         100.0                     10
#
#     Final_Marks
# 73        100.0
# 85        100.0
# 94        100.0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
ds['Study_Hours_Standardized']= scaler.fit_transform(ds[['Study_Hours']])
# Out:
# /tmp/ipykernel_1641/2248324779.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds['Study_Hours_Standardized']= scaler.fit_transform(ds[['Study_Hours']])

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()
ds['Marks_Normalized']= minmax.fit_transform(ds[['Final_Marks']])
# Out:
# /tmp/ipykernel_1641/2633996657.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds['Marks_Normalized']= minmax.fit_transform(ds[['Final_Marks']])
